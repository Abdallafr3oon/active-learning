# %% [markdown]
# # Imports

# %%
# !pip install -U scikit-activeml
# Out:
# Collecting scikit-activeml
#   Downloading scikit_activeml-0.4.1-py3-none-any.whl (252 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.7/252.7 kB 3.5 MB/s eta 0:00:00
# Collecting joblib<1.3,>=1.2 (from scikit-activeml)
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 17.9 MB/s eta 0:00:00
# Collecting numpy<1.25,>=1.22 (from scikit-activeml)
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 18.2 MB/s eta 0:00:00
# Collecting scipy<1.11,>=1.8 (from scikit-activeml)
#   Downloading scipy-1.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn<1.3,>=1.2 in /usr/local/lib/python3.10/dist-packages (from scikit-activeml) (1.2.2)
# Requirement already satisfied: matplotlib<3.8,>=3.5 in /usr/local/lib/python3.10/dist-packages (from scikit-activeml) (3.7.1)
# Collecting iteration-utilities<0.12,>=0.11 (from scikit-activeml)
#   Downloading iteration_utilities-0.11.0.tar.gz (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=3.5->scikit-activeml) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.3,>=1.2->scikit-activeml) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.8,>=3.5->scikit-activeml) (1.16.0)
# Building wheels for collected packages: iteration-utilities
#   Building wheel for iteration-utilities (setup.py) ... done
#   Created wheel for iteration-utilities: filename=iteration_utilities-0.11.0-cp310-cp310-linux_x86_64.whl size=327916 sha256=9424241a39e2b0c05fa9c1f892d1f17bc35d1bb1a99f7650031ae7f8ac5a7290
#   Stored in directory: /root/.cache/pip/wheels/2d/ab/c4/309aa5942beba1f36d6744acf619b7a314fca50f6a7ccce68c
# Successfully built iteration-utilities
# Installing collected packages: numpy, joblib, iteration-utilities, scipy, scikit-activeml
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# Successfully installed iteration-utilities-0.11.0 joblib-1.2.0 numpy-1.24.4 scikit-activeml-0.4.1 scipy-1.10.1

# %%
import pandas as pd
from sklearn.datasets import load_iris
import numpy as np
import matplotlib as mlp
import matplotlib.pyplot as plt

from skactiveml.pool import UncertaintySampling
from skactiveml.pool import QueryByCommittee

from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import BaggingClassifier
from skactiveml.classifier import SklearnClassifier, ParzenWindowClassifier

from skactiveml.utils import unlabeled_indices, labeled_indices, MISSING_LABEL
from skactiveml.visualization import plot_decision_boundary, plot_utilities

import warnings
mlp.rcParams["figure.facecolor"] = "white"
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load and Prepare Data

# %%
# Load the Breast Cancer dataset
data = load_iris()

# Convert to DataFrame
df = pd.DataFrame(data.data, columns=data.feature_names)

# Add target column to the DataFrame
df['target'] = data.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
target_counts = df['target'].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(target_counts, labels=df.target.unique(), autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Iris Classes')
plt.show()

# %% [markdown]
# # Entropy

# %%
X = df.drop(columns=['target']).values
y_true = df['target'].values

y = np.full(shape=y_true.shape, fill_value=MISSING_LABEL)

# %%
# clf_entropy = SklearnClassifier(LogisticRegression(), classes=np.unique(y_true))

clf_entropy = ParzenWindowClassifier(classes=np.unique(y_true), random_state=42)
# Initialise the query strategy.
qs_entropy = UncertaintySampling(method='entropy')

# %%
# score on the before querie data.
y = np.full(shape=y_true.shape, fill_value=MISSING_LABEL)
clf_entropy.fit(X, y)

unqueried_score = clf_entropy.score(X,y_true)
print(unqueried_score)
# Out:
# 0.2733333333333333

# %%
performance_history_entropy = [unqueried_score]

# %%
n_cycles = 100
for c in range(n_cycles):
  # Fit the classifier.
  clf_entropy.fit(X, y)

  model_accuracy = clf_entropy.score(X,y_true)
  print(f'Query {c+1}: The accuracy score is {model_accuracy}.')

  # Get labeled instances.
  X_labeled = X[labeled_indices(y)]

  # Query the next instance/s.
  query_idx = qs_entropy.query(X=X, y=y, clf=clf_entropy)

  # Label the queried instances.
# Query 69: The accuracy score is 0.6266666666666667.
# Query 70: The accuracy score is 0.6133333333333333.
# Query 71: The accuracy score is 0.6266666666666667.
# Query 72: The accuracy score is 0.62.
# Query 73: The accuracy score is 0.6266666666666667.
# Query 74: The accuracy score is 0.62.
# Query 75: The accuracy score is 0.62.
# Query 76: The accuracy score is 0.6133333333333333.
# Query 77: The accuracy score is 0.62.
# Query 78: The accuracy score is 0.62.
# Query 79: The accuracy score is 0.62.
# Query 80: The accuracy score is 0.62.
# Query 81: The accuracy score is 0.6066666666666667.
# Query 82: The accuracy score is 0.6133333333333333.
# Query 83: The accuracy score is 0.6066666666666667.
# Query 84: The accuracy score is 0.6133333333333333.
# Query 85: The accuracy score is 0.6133333333333333.
# Query 86: The accuracy score is 0.6133333333333333.
# Query 87: The accuracy score is 0.6066666666666667.
# Query 88: The accuracy score is 0.6066666666666667.
# Query 89: The accuracy score is 0.6.
# Query 90: The accuracy score is 0.6.
# Query 91: The accuracy score is 0.5933333333333334.
# Query 92: The accuracy score is 0.6.
# Query 93: The accuracy score is 0.5933333333333334.
# Query 94: The accuracy score is 0.6.
# Query 95: The accuracy score is 0.6.
# Query 96: The accuracy score is 0.6.
# Query 97: The accuracy score is 0.6.
# Query 98: The accuracy score is 0.6.
# Query 99: The accuracy score is 0.5933333333333334.
# Query 100: The accuracy score is 0.6.

# %%
# Plot our performance over time.
fig, ax = plt.subplots(figsize=(8.5, 6), dpi=130)

ax.plot(performance_history_entropy)
ax.scatter(range(len(performance_history_entropy)), performance_history_entropy, s=13)

ax.xaxis.set_major_locator(mlp.ticker.MaxNLocator(nbins=5, integer=True))
ax.yaxis.set_major_locator(mlp.ticker.MaxNLocator(nbins=10))
ax.yaxis.set_major_formatter(mlp.ticker.PercentFormatter(xmax=1))

ax.set_ylim(bottom=0, top=1)
ax.grid(True)

ax.set_title('Incremental classification accuracy for Entropy Sampling')
ax.set_xlabel('Query iteration')
ax.set_ylabel('Classification Accuracy')

plt.show()

# %% [markdown]
# # Margin Sampling

# %%
X = df.drop(columns=['target']).values
y_true = df['target'].values

y = np.full(shape=y_true.shape, fill_value=MISSING_LABEL)

# %%
# clf_margin = SklearnClassifier(LogisticRegression(), classes=np.unique(y_true))

clf_margin = ParzenWindowClassifier(classes=np.unique(y_true), random_state=42)
# Initialise the query strategy.
qs_margin = UncertaintySampling(method='margin_sampling')

# %%
# score on the before querie data.
y = np.full(shape=y_true.shape, fill_value=MISSING_LABEL)
clf_margin.fit(X, y)

unqueried_score = clf_margin.score(X,y_true)
print(unqueried_score)
# Out:
# 0.2733333333333333

# %%
performance_history_margin = [unqueried_score]

# %%
n_cycles = 100
for c in range(n_cycles):
  # Fit the classifier.
  clf_margin.fit(X, y)

  model_accuracy = clf_margin.score(X,y_true)
  print(f'Query {c+1}: The accuracy score is {model_accuracy}.')

  # Get labeled instances.
  X_labeled = X[labeled_indices(y)]

  # Query the next instance/s.
  query_idx = qs_margin.query(X=X, y=y, clf=clf_margin)

  # Label the queried instances.
  y[query_idx] = y_true[query_idx]

  # Save our model's performance for plotting.
  performance_history_margin.append(model_accuracy)
# Out:
# Query 1: The accuracy score is 0.2733333333333333.
# Query 2: The accuracy score is 0.3333333333333333.
# Query 3: The accuracy score is 0.6666666666666666.
# Query 4: The accuracy score is 0.8666666666666667.
# Query 5: The accuracy score is 0.8666666666666667.
# Query 6: The accuracy score is 0.9266666666666666.
# Query 7: The accuracy score is 0.8866666666666667.
# Query 8: The accuracy score is 0.9266666666666666.
# Query 9: The accuracy score is 0.9.
# Query 10: The accuracy score is 0.9333333333333333.
# Query 11: The accuracy score is 0.9066666666666666.
# Query 12: The accuracy score is 0.96.
# Query 13: The accuracy score is 0.9133333333333333.
# Query 14: The accuracy score is 0.96.
# Query 86: The accuracy score is 0.9533333333333334.
# Query 87: The accuracy score is 0.9533333333333334.
# Query 88: The accuracy score is 0.9533333333333334.
# Query 89: The accuracy score is 0.94.
# Query 90: The accuracy score is 0.9466666666666667.
# Query 91: The accuracy score is 0.94.
# Query 92: The accuracy score is 0.94.
# Query 93: The accuracy score is 0.9466666666666667.
# Query 94: The accuracy score is 0.9333333333333333.
# Query 95: The accuracy score is 0.9466666666666667.
# Query 96: The accuracy score is 0.94.
# Query 97: The accuracy score is 0.94.
# Query 98: The accuracy score is 0.94.
# Query 99: The accuracy score is 0.9333333333333333.
# Query 100: The accuracy score is 0.9333333333333333.

# %%
# Plot our performance over time.
fig, ax = plt.subplots(figsize=(8.5, 6), dpi=130)

ax.plot(performance_history_margin)
ax.scatter(range(len(performance_history_margin)), performance_history_margin, s=13)

ax.xaxis.set_major_locator(mlp.ticker.MaxNLocator(nbins=5, integer=True))
ax.yaxis.set_major_locator(mlp.ticker.MaxNLocator(nbins=10))
ax.yaxis.set_major_formatter(mlp.ticker.PercentFormatter(xmax=1))

ax.set_ylim(bottom=0, top=1)
ax.grid(True)

ax.set_title('Incremental classification accuracy for Margin Sampling')
ax.set_xlabel('Query iteration')
ax.set_ylabel('Classification Accuracy')

plt.show()

# %% [markdown]
# # Query by Committee

# %%
X = df.drop(columns=['target']).values
y_true = df['target'].values

y = np.full(shape=y_true.shape, fill_value=MISSING_LABEL)

# %%
clf_committee = SklearnClassifier(BaggingClassifier(ParzenWindowClassifier()), classes=np.unique(y_true))

# Initialise the query strategy.
qs_committee = QueryByCommittee(random_state=42)

# %%
# score on the before querie data.
y = np.full(shape=y_true.shape, fill_value=MISSING_LABEL)
clf_committee.fit(X, y)

unqueried_score = clf_committee.score(X,y_true)
print(unqueried_score)
# Out:
# 0.4066666666666667

# %%
performance_history_committee = [unqueried_score]

# %%
n_cycles = 100
for c in range(n_cycles):
  # Fit the classifier.
  clf_committee.fit(X, y)

  model_accuracy = clf_committee.score(X,y_true)
  print(f'Query {c+1}: The accuracy score is {model_accuracy}.')

  # Get labeled instances.
  X_labeled = X[labeled_indices(y)]

  # Query the next instance/s.
  query_idx = qs_committee.query(X=X, y=y, ensemble=clf_committee)

  # Label the queried instances.
  y[query_idx] = y_true[query_idx]

  # Save our model's performance for plotting.
  performance_history_committee.append(model_accuracy)
# Out:
# Query 1: The accuracy score is 0.3333333333333333.
# Query 2: The accuracy score is 0.3333333333333333.
# Query 3: The accuracy score is 0.3333333333333333.
# Query 4: The accuracy score is 0.64.
# Query 5: The accuracy score is 0.8333333333333334.
# Query 6: The accuracy score is 0.8933333333333333.
# Query 7: The accuracy score is 0.8733333333333333.
# Query 8: The accuracy score is 0.78.
# Query 9: The accuracy score is 0.86.
# Query 10: The accuracy score is 0.8733333333333333.
# Query 11: The accuracy score is 0.6733333333333333.
# Query 12: The accuracy score is 0.8.
# Query 13: The accuracy score is 0.9266666666666666.
# Query 14: The accuracy score is 0.9333333333333333.
# Query 15: The accuracy score is 0.9266666666666666.
# Query 16: The accuracy score is 0.9466666666666667.
# Query 17: The accuracy score is 0.82.
# Query 18: The accuracy score is 0.8666666666666667.
# Query 19: The accuracy score is 0.9.
# Query 20: The accuracy score is 0.92.
# Query 21: The accuracy score is 0.8466666666666667.
# Query 22: The accuracy score is 0.9333333333333333.
# Query 23: The accuracy score is 0.9333333333333333.
# Query 24: The accuracy score is 0.9333333333333333.
# Query 25: The accuracy score is 0.88.
# Query 26: The accuracy score is 0.9.
# Query 27: The accuracy score is 0.9066666666666666.
# Query 28: The accuracy score is 0.9133333333333333.
# Query 29: The accuracy score is 0.8933333333333333.
# Query 30: The accuracy score is 0.88.
# Query 31: The accuracy score is 0.9133333333333333.
# Query 32: The accuracy score is 0.9133333333333333.
# Query 33: The accuracy score is 0.9.
# Query 34: The accuracy score is 0.9.
# Query 35: The accuracy score is 0.9.
# Query 36: The accuracy score is 0.9333333333333333.
# Query 37: The accuracy score is 0.9266666666666666.
# Query 38: The accuracy score is 0.9266666666666666.
# Query 39: The accuracy score is 0.9333333333333333.
# Query 40: The accuracy score is 0.9266666666666666.
# Query 41: The accuracy score is 0.92.
# Query 42: The accuracy score is 0.9066666666666666.
# Query 43: The accuracy score is 0.92.
# Query 44: The accuracy score is 0.9066666666666666.
# Query 45: The accuracy score is 0.9.
# Query 46: The accuracy score is 0.9133333333333333.
# Query 47: The accuracy score is 0.9.
# Query 48: The accuracy score is 0.9.
# Query 49: The accuracy score is 0.9.
# Query 50: The accuracy score is 0.9066666666666666.
# Query 51: The accuracy score is 0.9066666666666666.
# Query 52: The accuracy score is 0.9.
# Query 53: The accuracy score is 0.8933333333333333.
# Query 54: The accuracy score is 0.9133333333333333.
# Query 55: The accuracy score is 0.9266666666666666.
# Query 56: The accuracy score is 0.9266666666666666.
# Query 57: The accuracy score is 0.9.
# Query 58: The accuracy score is 0.9066666666666666.
# Query 59: The accuracy score is 0.9333333333333333.
# Query 60: The accuracy score is 0.9.
# Query 61: The accuracy score is 0.9.
# Query 62: The accuracy score is 0.9066666666666666.
# Query 63: The accuracy score is 0.9266666666666666.
# Query 64: The accuracy score is 0.92.
# Query 65: The accuracy score is 0.9.
# Query 66: The accuracy score is 0.9.
# Query 67: The accuracy score is 0.9.
# Query 68: The accuracy score is 0.9066666666666666.
# Query 69: The accuracy score is 0.9066666666666666.
# Query 70: The accuracy score is 0.9066666666666666.
# Query 71: The accuracy score is 0.9066666666666666.
# Query 72: The accuracy score is 0.9066666666666666.
# Query 73: The accuracy score is 0.9.
# Query 74: The accuracy score is 0.9.
# Query 75: The accuracy score is 0.8733333333333333.
# Query 76: The accuracy score is 0.88.
# Query 77: The accuracy score is 0.9.
# Query 78: The accuracy score is 0.88.
# Query 79: The accuracy score is 0.9.
# Query 80: The accuracy score is 0.9066666666666666.
# Query 81: The accuracy score is 0.8933333333333333.
# Query 82: The accuracy score is 0.9.
# Query 83: The accuracy score is 0.9133333333333333.
# Query 84: The accuracy score is 0.88.
# Query 85: The accuracy score is 0.9.
# Query 86: The accuracy score is 0.9133333333333333.
# Query 87: The accuracy score is 0.86.
# Query 88: The accuracy score is 0.9.
# Query 89: The accuracy score is 0.9066666666666666.
# Query 90: The accuracy score is 0.9.
# Query 91: The accuracy score is 0.9.
# Query 92: The accuracy score is 0.8866666666666667.
# Query 93: The accuracy score is 0.9133333333333333.
# Query 94: The accuracy score is 0.9066666666666666.
# Query 95: The accuracy score is 0.9066666666666666.
# Query 96: The accuracy score is 0.9133333333333333.
# Query 97: The accuracy score is 0.9066666666666666.
# Query 98: The accuracy score is 0.9066666666666666.
# Query 99: The accuracy score is 0.9066666666666666.
# Query 100: The accuracy score is 0.9.

# %%
# Plot our performance over time.
fig, ax = plt.subplots(figsize=(8.5, 6), dpi=130)

ax.plot(performance_history_committee)
ax.scatter(range(len(performance_history_committee)), performance_history_committee, s=13)

ax.xaxis.set_major_locator(mlp.ticker.MaxNLocator(nbins=5, integer=True))
ax.yaxis.set_major_locator(mlp.ticker.MaxNLocator(nbins=10))
ax.yaxis.set_major_formatter(mlp.ticker.PercentFormatter(xmax=1))

ax.set_ylim(bottom=0, top=1)
ax.grid(True)

ax.set_title('Incremental classification accuracy for Query by Committee Sampling')
ax.set_xlabel('Query iteration')
ax.set_ylabel('Classification Accuracy')

plt.show()
